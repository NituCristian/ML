# %%
# Load libraries
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-19cad7aa-daa6-493e-a322-1a1ded1464a9" name="files[]" multiple disabled />
#      <output id="result-19cad7aa-daa6-493e-a322-1a1ded1464a9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving breastCancer.csv to breastCancer (2).csv

# %%
import io
breast = pd.read_csv(io.BytesIO(uploaded['breastCancer.csv']))
col_names = ['Age', 'BMI', 'Glucose', 'Insulin', 'HOMA', 'Leptin', 'Adiponectin', 'Resistin', 'MCP.1', 'Classification']
breast.columns = col_names

# %%
breast.head()
# Out:
#    Age        BMI  Glucose  ...  Resistin    MCP.1  Classification
# 0   48  23.500000       70  ...   7.99585  417.114               1
# 1   83  20.690495       92  ...   4.06405  468.786               1
# 2   82  23.124670       91  ...   9.27715  554.697               1
# 3   68  21.367521       77  ...  12.76600  928.220               1
# 4   86  21.111111       92  ...  10.57635  773.920               1
#
# [5 rows x 10 columns]

# %%
#split dataset in features and target variable
feature_cols = ['Age', 'BMI', 'Glucose', 'Insulin','HOMA', 'Leptin', 'MCP.1']
X = breast[feature_cols] # Features
y = breast.Classification # Target variable

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=1) # 85% training and 15% test

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7222222222222222

# %%
from sklearn.tree import export_graphviz
from sklearn.externals.six import StringIO  
from IPython.display import Image  
import pydotplus

dot_data = StringIO()
export_graphviz(clf, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True,feature_names = feature_cols,class_names=['0','1'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('breastCancer.png')
Image(graph.create_png())

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier(criterion="gini", max_depth=3)

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7777777777777778

# %%
from sklearn.externals.six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus
dot_data = StringIO()
export_graphviz(clf, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True, feature_names = feature_cols,class_names=['0','1'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('breast.png')
Image(graph.create_png())
